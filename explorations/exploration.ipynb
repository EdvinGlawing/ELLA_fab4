# %% [markdown]
# # EDA

# %%
import requests
import json
import pandas as pd

with open("../data/raw_data/brottsbalken.json", encoding="utf-8") as f:
    data = json.load(f)

# df = pd.json_normalize(data)
# df = pd.DataFrame(data)

df = pd.json_normalize(
    data["kapitel"],
    record_path="paragraphs",
    meta=["chapter_number", "title"],
    errors="ignore"
)

# %%
df.sample(10)
# Out:
#     paragraph                                               text  \
# 82       15 §  För försök till våldtäkt, grov våldtäkt, sexue...
# 460      12 §  Bestämmelser om verkställighet av säkerhetsför...
# 77     10 a §  Den som, i syfte att mot ett barn under femton...
# 526       6 §  Om den dömde begär det, har han eller hon rätt...
# 292       7 §  Avviker eller uteblir en krigsman olovligen fr...
# 20       13 §  I fråga om utlämning och överlämnande finns sä...
# 331      19 §                har upphävts genom _lag (1973:17)_.
# 530      10 §  Kriminalvårdens beslut som avses i 7 § och öve...
# 33        1 §  Den som bemäktigar sig och för bort eller spär...
# 329      17 §               har upphävts genom _lag (1986:645)_.
#
#            law_references  repealed chapter_number  \
# 82    [_Lag (2025:586)_.]     False              6
# 460   [_Lag (2026:253)_.]     False             33
# 77   [_Lag (2017:1068)_.]     False              6
# 526   [_Lag (2010:612)_.]     False             37
# 292   [_Lag (1986:645)_.]     False             21
# 20   [_Lag (2021:1014)_.]     False              2
# 331                    []      True             22
# 530   [_Lag (2021:249)_.]     False             37
# 33    [_Lag (2009:396)_.]     False              4
# 329                    []      True             22
#
#                                     title
# 82                  6 kap. Om sexualbrott
# 460         33 kap. Om säkerhetsförvaring
# 77                  6 kap. Om sexualbrott
# 526                  37 kap. Om nämnderna
# 292          21 kap. Om brott av krigsmän
# 20   2 kap. Om svensk domstols behörighet
# 331       22 kap. Om landsförräderi m. m.
# 530                  37 kap. Om nämnderna
# 33    4 kap. Om brott mot frihet och frid
# 329       22 kap. Om landsförräderi m. m.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   paragraph       556 non-null    object
#  1   text            556 non-null    object
#  2   law_references  556 non-null    object
#  3   repealed        556 non-null    bool
#  4   chapter_number  556 non-null    object
#  5   title           556 non-null    object
# dtypes: bool(1), object(5)
# memory usage: 22.4+ KB

# %% [markdown]
# ## Cleaning the data

# %%
df.drop(columns=["repealed"], inplace=True)

# %%
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   paragraph       556 non-null    object
#  1   text            556 non-null    object
#  2   law_references  556 non-null    object
#  3   chapter_number  556 non-null    object
#  4   title           556 non-null    object
# dtypes: object(5)
# memory usage: 21.8+ KB

# %%
df
# Out:
#     paragraph                                               text  \
# 0         1 §  Brott är en gärning som är beskriven i denna b...
# 1         2 §  En gärning skall, om inte annat är särskilt fö...
# 2         3 §  Med påföljd för brott förstås i denna balk str...
# 3         4 §  Om användningen av straffen gäller vad i bestä...
# 4         5 §  Fängelse är att anse som ett svårare straff än...
# ..        ...                                                ...
# 551      16 §  En begäran om omprövning skall vara skriftlig ...
# 552      17 §  Kriminalvården prövar om skrivelsen med begära...
# 553      18 §  Beslut som avses i 14 § överklagas till den fö...
# 554      19 §  Mål om uppskjuten villkorlig frigivning enligt...
# 555      20 §  Regeringen eller den myndighet som regeringen ...
#
#           law_references chapter_number                                title
# 0    [_Lag (1994:458)_.]              1  1 kap. Om brott och brottspåföljder
# 1    [_Lag (1994:458)_.]              1  1 kap. Om brott och brottspåföljder
# 2    [_Lag (2026:253)_.]              1  1 kap. Om brott och brottspåföljder
# 3    [_Lag (1988:942)_.]              1  1 kap. Om brott och brottspåföljder
# 4    [_Lag (2026:253)_.]              1  1 kap. Om brott och brottspåföljder
# ..                   ...            ...                                  ...
# 551  [_Lag (2005:967)_.]             38  38 kap. Rättegångsbestämmelser m.m.
# 552  [_Lag (2005:967)_.]             38  38 kap. Rättegångsbestämmelser m.m.
# 553  [_Lag (2009:776)_.]             38  38 kap. Rättegångsbestämmelser m.m.
# 554  [_Lag (2021:249)_.]             38  38 kap. Rättegångsbestämmelser m.m.
# 555  [_Lag (2006:892)_.]             38  38 kap. Rättegångsbestämmelser m.m.
#
# [556 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   paragraph       556 non-null    object
#  1   text            556 non-null    object
#  2   law_references  556 non-null    object
#  3   chapter_number  556 non-null    object
#  4   title           556 non-null    object
# dtypes: object(5)
# memory usage: 21.8+ KB

# %% [markdown]
# ## Remove chapter number and 'kap' from title

# %%
df["title"] = df["title"].str.replace(r'^(\d+\s*)?(kap\.\s*)?(\d+\s*)?', '', regex=True)

# %%
df
# Out:
#     paragraph                                               text  \
# 0         1 §  Brott är en gärning som är beskriven i denna b...
# 1         2 §  En gärning skall, om inte annat är särskilt fö...
# 2         3 §  Med påföljd för brott förstås i denna balk str...
# 3         4 §  Om användningen av straffen gäller vad i bestä...
# 4         5 §  Fängelse är att anse som ett svårare straff än...
# ..        ...                                                ...
# 551      16 §  En begäran om omprövning skall vara skriftlig ...
# 552      17 §  Kriminalvården prövar om skrivelsen med begära...
# 553      18 §  Beslut som avses i 14 § överklagas till den fö...
# 554      19 §  Mål om uppskjuten villkorlig frigivning enligt...
# 555      20 §  Regeringen eller den myndighet som regeringen ...
#
#           law_references chapter_number                         title
# 0    [_Lag (1994:458)_.]              1  Om brott och brottspåföljder
# 1    [_Lag (1994:458)_.]              1  Om brott och brottspåföljder
# 2    [_Lag (2026:253)_.]              1  Om brott och brottspåföljder
# 3    [_Lag (1988:942)_.]              1  Om brott och brottspåföljder
# 4    [_Lag (2026:253)_.]              1  Om brott och brottspåföljder
# ..                   ...            ...                           ...
# 551  [_Lag (2005:967)_.]             38   Rättegångsbestämmelser m.m.
# 552  [_Lag (2005:967)_.]             38   Rättegångsbestämmelser m.m.
# 553  [_Lag (2009:776)_.]             38   Rättegångsbestämmelser m.m.
# 554  [_Lag (2021:249)_.]             38   Rättegångsbestämmelser m.m.
# 555  [_Lag (2006:892)_.]             38   Rättegångsbestämmelser m.m.
#
# [556 rows x 5 columns]

# %%
df["chapter_number"] = df["chapter_number"].astype(str) + " kap."

# %%
df
# Out:
#     paragraph                                               text  \
# 0         1 §  Brott är en gärning som är beskriven i denna b...
# 1         2 §  En gärning skall, om inte annat är särskilt fö...
# 2         3 §  Med påföljd för brott förstås i denna balk str...
# 3         4 §  Om användningen av straffen gäller vad i bestä...
# 4         5 §  Fängelse är att anse som ett svårare straff än...
# ..        ...                                                ...
# 551      16 §  En begäran om omprövning skall vara skriftlig ...
# 552      17 §  Kriminalvården prövar om skrivelsen med begära...
# 553      18 §  Beslut som avses i 14 § överklagas till den fö...
# 554      19 §  Mål om uppskjuten villkorlig frigivning enligt...
# 555      20 §  Regeringen eller den myndighet som regeringen ...
#
#           law_references chapter_number                         title
# 0    [_Lag (1994:458)_.]         1 kap.  Om brott och brottspåföljder
# 1    [_Lag (1994:458)_.]         1 kap.  Om brott och brottspåföljder
# 2    [_Lag (2026:253)_.]         1 kap.  Om brott och brottspåföljder
# 3    [_Lag (1988:942)_.]         1 kap.  Om brott och brottspåföljder
# 4    [_Lag (2026:253)_.]         1 kap.  Om brott och brottspåföljder
# ..                   ...            ...                           ...
# 551  [_Lag (2005:967)_.]        38 kap.   Rättegångsbestämmelser m.m.
# 552  [_Lag (2005:967)_.]        38 kap.   Rättegångsbestämmelser m.m.
# 553  [_Lag (2009:776)_.]        38 kap.   Rättegångsbestämmelser m.m.
# 554  [_Lag (2021:249)_.]        38 kap.   Rättegångsbestämmelser m.m.
# 555  [_Lag (2006:892)_.]        38 kap.   Rättegångsbestämmelser m.m.
#
# [556 rows x 5 columns]

# %%
df.to_json(
    "../data/clean_data/brottsbalken_clean.json",
    orient="records",
    indent=4,
    force_ascii=False
)
