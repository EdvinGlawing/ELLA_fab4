# %%
import mlflow

experiment = mlflow.get_experiment_by_name("brottsbalken")
experiment
# Out:
# <Experiment: artifact_location='file:C:/MLOps_2025/ELLA_fab4/src/brottsbalken/backend/mlruns/2', creation_time=1778149285896, experiment_id='2', last_update_time=1778149285896, lifecycle_stage='active', name='brottsbalken', tags={}, trace_location=None, workspace='default'>

# %%
traces = mlflow.search_traces(locations=[experiment.experiment_id])
traces.head()
# Out:
#                               trace_id  \
# 0  tr-d94451a02e27dd50c5d41b1e1f10e9e3
# 1  tr-8b8679b80ff964d338d163a7e68eaddc
# 2  tr-68e155e6ee956677503b01754d77420d
# 3  tr-b7d589cd2f455cabaac9ff7b2bc49bb3
# 4  tr-47ffaaaab34001fc33e95a67f63be075
#
#                                                trace client_request_id  state  \
# 0  {"info": {"trace_id": "tr-d94451a02e27dd50c5d4...              None     OK
# 1  {"info": {"trace_id": "tr-8b8679b80ff964d338d1...              None     OK
# 2  {"info": {"trace_id": "tr-68e155e6ee956677503b...              None     OK
# 3  {"info": {"trace_id": "tr-b7d589cd2f455cabaac9...              None     OK
# 4  {"info": {"trace_id": "tr-47ffaaaab34001fc33e9...              None  ERROR
#
#     request_time  execution_duration  \
# 0  1778242653090                4421
# 1  1778242136842                9953
# 2  1778242073886                7839
# 3  1778241881832               15122
# 4  1778241758192                 105
#
#                                              request  \
# 0  {'user_prompt': '
# Fråga:
# vad är straffet mord?...
# 1  {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 2  {'user_prompt': '
# Fråga:
# vad är straffet för a...
# 3  {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 4  {'user_prompt': '
# Fråga:
# vad är straffet för m...
#
#                                             response  \
# 0  {'output': {'answer': 'Straffet för mord är fä...
# 1  {'output': {'answer': 'Straffet för mordbrand ...
# 2  {'output': {'answer': 'Jag hittar inget stöd i...
# 3  {'output': {'answer': 'Enligt 3 kap. 1 § Brott...
# 4                                               None
#
#                                       trace_metadata  \
# 0  {'mlflow.trace.tokenUsage': '{"input_tokens": ...
# 1  {'mlflow.trace.tokenUsage': '{"input_tokens": ...
# 2  {'mlflow.trace.tokenUsage': '{"input_tokens": ...
# 3  {'mlflow.trace.tokenUsage': '{"input_tokens": ...
# 4  {'mlflow.user': 'edvin', 'mlflow.source.name':...
#
#                                                 tags  \
# 0  {'mlflow.artifactLocation': 'file:C:/MLOps_202...
# 1  {'mlflow.artifactLocation': 'file:C:/MLOps_202...
# 2  {'mlflow.artifactLocation': 'file:C:/MLOps_202...
# 3  {'mlflow.artifactLocation': 'file:C:/MLOps_202...
# 4  {'mlflow.artifactLocation': 'file:C:/MLOps_202...
#
#                                                spans assessments
# 0  [{'trace_id': '2URRoC4n3VDF1BseHxDp4w==', 'spa...          []
# 1  [{'trace_id': 'i4Z5uA/5ZNM40WOn5o6t3A==', 'spa...          []
# 2  [{'trace_id': 'aOFV5u6VZndQOwF1TXdCDQ==', 'spa...          []
# 3  [{'trace_id': 't9WJzS9FXKuqyf97K8Sbsw==', 'spa...          []
# 4  [{'trace_id': 'R/+qqrNAAfwz6Vpn9jvgdQ==', 'spa...          []

# %%
traces["request"]
# Out:
# 0     {'user_prompt': '
# Fråga:
# vad är straffet mord?...
# 1     {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 2     {'user_prompt': '
# Fråga:
# vad är straffet för a...
# 3     {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 4     {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 5     {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 6     {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 7     {'user_prompt': '
# Fråga:
# vad är straffet för s...
# 8     {'user_prompt': '
# Fråga:
# vad är straffet för s...
# 9     {'user_prompt': '
# Fråga:
# vad är straff
#
# Releva...
# 10    {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 11    {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 12    {'user_prompt': '
# Fråga:
# vad äter tigrar?
#
# Rel...
# 13    {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 14    {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 15    {'user_prompt': '
# Fråga:
# Vad är straffet för v...
# 16    {'user_prompt': '
# Fråga:
# Vad är ett rån?
#
# Rele...
# 17    {'user_prompt': '
# Fråga:
# Vad är ett mord
#
# Rele...
# 18    {'user_prompt': '
# Fråga:
# Vad är straffet för m...
# 19    {'user_prompt': '
# Fråga:
# Vad är straffet för m...
# 20    {'user_prompt': '
# Fråga:
# Vad är straffet för m...
# 21    {'user_prompt': '
# Fråga:
# hej på dig
#
# Relevant ...
# 22    {'user_prompt': '
# Fråga:
# vad är straffet för m...
# 23    {'user_prompt': '
# Fråga:
# vad händer om jag slå...
# 24    {'user_prompt': '
# Fråga:
# vad är det för straff...
# 25    {'user_prompt': '
# Fråga:
# vad händer om jag rån...
# 26    {'user_prompt': '
# Fråga:
# Vad äter tigrar?
#
# Rel...
# 27    {'user_prompt': '
# Fråga:
# Vad äter tigrar?
#
# Rel...
# 28    {'user_prompt': '
# Fråga:
# Vad är straffet för m...
# Name: request, dtype: object

# %%
import json

with open("evaluation_data_short.json") as file:
    eval_data = json.load(file)

eval_data
# Out:
# [{'inputs': {'question': 'Vad Ã¤r straffet fÃ¶r mord?'},
#   'expectations': {'expected_source': '3 kap. 1 Â§ brottsbalken',
#    'expected_keywords': ['mord', 'fÃ¤ngelse', 'livstid']}},
#  {'inputs': {'question': 'Vad sÃ¤ger Brottsbalken om stÃ¶ld?'},
#   'expectations': {'expected_source': '8 kap. 1 Â§ brottsbalken',
#    'expected_keywords': ['stÃ¶ld', 'olovligen', 'tillgrepp']}},
#  {'inputs': {'question': 'Vad Ã¤r misshandel?'},
#   'expectations': {'expected_source': '3 kap. 5 Â§ brottsbalken',
#    'expected_keywords': ['misshandel', 'kroppsskada', 'sjukdom', 'smÃ¤rta']}},
#  {'inputs': {'question': 'Vad Ã¤r olaga hot?'},
#   'expectations': {'expected_source': '4 kap. 5 Â§ brottsbalken',
#    'expected_keywords': ['olaga hot', 'hotar', 'brottslig gÃ¤rning']}},
#  {'inputs': {'question': 'Vad Ã¤ter tigrar?'},
#   'expectations': {'expected_source': 'N/A',
#    'expected_keywords': ['hittar inget stÃ¶d',
#     'Brottsbalken',
#     'avvisa frÃ¥gan']}}]

# %%
from mlflow.genai.datasets import create_dataset

evaluation_dataset = create_dataset(
    name = "brottsbalken_v3",
    experiment_id=experiment.experiment_id,
    tags={
    "stage": "validation",
    "domain": "brottsbalken",
    "task": "rag-evaluation",
    "language": "sv",
}
)

evaluation_dataset

# %%
evaluation_dataset.merge_records(eval_data)

# %%
import sys
from pathlib import Path

cwd = Path.cwd().resolve()

for path in [cwd, *cwd.parents]:
    candidate = path / "src" / "brottsbalken"
    if candidate.exists():
        SRC_ROOT = path / "src"
        break
else:
    raise RuntimeError("Could not find src/brottsbalken")

sys.path.insert(0, str(SRC_ROOT))
print("Added:", SRC_ROOT)
# Out:
# Added: C:\Users\edvin\.vscode\ELLA_fab4\src

# %%
from mlflow.genai import evaluate
from mlflow.genai.scorers import Correctness, Guidelines
from brottsbalken.backend.agents import law_agent
from brottsbalken.backend.constants import LLM_JUDGE


async def bot_answer(question: str) -> str:
    result = await law_agent.run(question)
    return result.output


scorers = [
    Correctness(name="factual_accuracy", model=LLM_JUDGE),
    Guidelines(
        name="law_quality",
        guidelines="""Response must be helpful, accurate, and professional.
        It must also refuse or redirect questions not related to 
        [brott, straff, lagrum, brottsbalken, juridik].
        
        The response should:
        - Always reference the correct chapter and paragraph (kap. och §)
        - Use correct Swedish legal terminology
        - Never give personal legal advice or act as a lawyer
        - Clearly state when something falls outside brottsbalken
        - Refuse to help plan, execute or justify criminal activity
        """,
        model=LLM_JUDGE,
    ),
]

mlflow.set_experiment(experiment_name="law_agent_eval")

results = evaluate(data=evaluation_dataset, predict_fn=bot_answer, scorers=scorers)
results
# Out:
# 2026/05/08 14:17:57 INFO mlflow.genai.scorers.validation: The input data is missing following columns that are required by the specified scorers. The results will be null for those scorers.
#  - `expected_response or expected_facts` field in `expectations` column is required by [factual_accuracy].
# 2026/05/08 14:17:57 INFO mlflow.genai.utils.data_validation: Testing model prediction with the first sample in the dataset. To disable this check, set the MLFLOW_GENAI_EVAL_SKIP_TRACE_VALIDATION environment variable to True.
# Traceback (most recent call last):
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\models\google.py", line 563, in _generate_content
#     return await func(model=self._model_name, contents=contents, config=config)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 634, in async_safe_patch_function
#     await patch_function(call_original, *args, **kwargs)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\gemini\autolog.py", line 62, in async_patched_class_call
#     output = await original(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 623, in call_original
#     return await call_original_fn_with_event_logging(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 590, in call_original_fn_with_event_logging
#     original_fn_result = await original_fn(*og_args, **og_kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 620, in _original_fn
#     original_result = await original(*_og_args, **_og_kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\models.py", line 8337, in generate_content
#     return await self._generate_content(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 634, in async_safe_patch_function
#     await patch_function(call_original, *args, **kwargs)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\gemini\autolog.py", line 62, in async_patched_class_call
#     output = await original(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 623, in call_original
#     return await call_original_fn_with_event_logging(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 590, in call_original_fn_with_event_logging
#     original_fn_result = await original_fn(*og_args, **og_kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 620, in _original_fn
#     original_result = await original(*_og_args, **_og_kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\models.py", line 6897, in _generate_content
#     response = await self._api_client.async_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\_api_client.py", line 1583, in async_request
#     result = await self._async_request(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\_api_client.py", line 1516, in _async_request
#     return await self._async_retry(  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\asyncio\__init__.py", line 112, in __call__
#     do = await self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\asyncio\__init__.py", line 157, in iter
#     result = await action(retry_state)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\_utils.py", line 111, in inner
#     return call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\__init__.py", line 413, in exc_check
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\__init__.py", line 184, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\tenacity\asyncio\__init__.py", line 116, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\_api_client.py", line 1496, in _async_request_once
#     await errors.APIError.raise_for_async_response(client_response)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\errors.py", line 247, in raise_for_async_response
#     await cls.raise_error_async(status_code, response_json, response)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\google\genai\errors.py", line 269, in raise_error_async
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 2.159599537s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '2s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\tracing\fluent.py", line 576, in start_span
#     yield mlflow_span
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\pydantic_ai\autolog.py", line 144, in patched_async_class_call
#     result = await original(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 623, in call_original
#     return await call_original_fn_with_event_logging(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 590, in call_original_fn_with_event_logging
#     original_fn_result = await original_fn(*og_args, **og_kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 620, in _original_fn
#     original_result = await original(*_og_args, **_og_kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\agent\abstract.py", line 377, in run
#     node = await agent_run.next(node)  # pyright: ignore[reportArgumentType]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\run.py", line 380, in next
#     return await self._run_node_with_hooks(node, self._advance_graph)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\run.py", line 306, in _run_node_with_hooks
#     return await self._wrap_and_advance(run_context, node, step_fn)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\run.py", line 276, in _wrap_and_advance
#     result = await cap.on_node_run_error(run_context, node=node, error=e)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 228, in on_node_run_error
#     raise error
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 225, in on_node_run_error
#     return await capability.on_node_run_error(ctx, node=node, error=error)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\abstract.py", line 396, in on_node_run_error
#     raise error
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\run.py", line 274, in _wrap_and_advance
#     result = await cap.wrap_node_run(run_context, node=node, handler=step_fn)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 214, in wrap_node_run
#     return await chain(node)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 469, in wrapped
#     return await cap.wrap_node_run(ctx, node=node, handler=inner)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\abstract.py", line 375, in wrap_node_run
#     return await handler(node)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\run.py", line 252, in _advance_graph
#     task = await self._graph_run.next(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 515, in next
#     return await anext(self)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 492, in __anext__
#     raise self._next.error
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 802, in _run_tracked_task
#     result = await self._run_task(t_)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 843, in _run_task
#     output = await node.call(step_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_graph\beta\step.py", line 253, in _call_node
#     return await node.run(GraphRunContext(state=ctx.state, deps=ctx.deps))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 529, in run
#     return await self._make_request(ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 745, in _make_request
#     model_response = await ctx.deps.root_capability.on_model_request_error(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 289, in on_model_request_error
#     raise error
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 286, in on_model_request_error
#     return await capability.on_model_request_error(ctx, request_context=request_context, error=error)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\abstract.py", line 477, in on_model_request_error
#     raise error
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 735, in _make_request
#     model_response = await ctx.deps.root_capability.wrap_model_request(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 275, in wrap_model_request
#     return await chain(request_context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 433, in wrapped
#     return await cap.wrap_model_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\capabilities\abstract.py", line 454, in wrap_model_request
#     return await handler(request_context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 721, in model_handler
#     response = await req_ctx.model.request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\models\google.py", line 363, in request
#     response = await self._generate_content(messages, False, model_settings, model_request_parameters)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\pydantic_ai\models\google.py", line 566, in _generate_content
#     raise ModelHTTPError(
# pydantic_ai.exceptions.ModelHTTPError: status_code: 429, model_name: gemini-3-flash-preview, body: {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 2.159599537s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '2s'}]}}
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\data_validation.py", line 30, in check_model_prediction
#     _check()
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\tracing\provider.py", line 861, in wrapper
#     result = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\data_validation.py", line 27, in _check
#     predict_fn(**sample_input)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\trace_utils.py", line 551, in sync_wrapper
#     return asyncio.run(asyncio.wait_for(async_fn(*args, **kwargs), timeout=timeout))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\nest_asyncio.py", line 98, in run_until_complete
#     return f.result()
#            ^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\asyncio\futures.py", line 203, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Program Files\Python312\Lib\asyncio\tasks.py", line 314, in __step_run_and_handle_result
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\asyncio\tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "C:\Users\edvin\AppData\Local\Temp\ipykernel_30256\3200852116.py", line 8, in bot_answer
#     result = await law_agent.run(question)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\utils\autologging_utils\safety.py", line 634, in async_safe_patch_function
#     await patch_function(call_original, *args, **kwargs)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\pydantic_ai\autolog.py", line 139, in patched_async_class_call
#     with mlflow.start_span(name=fullname, span_type=span_type) as span:
#   File "C:\Program Files\Python312\Lib\contextlib.py", line 194, in __exit__
#     raise RuntimeError("generator didn't stop after throw()")
# RuntimeError: generator didn't stop after throw()
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\edvin\AppData\Local\Temp\ipykernel_30256\3200852116.py", line 33, in <module>
#     results = evaluate(data=evaluation_dataset, predict_fn=bot_answer, scorers=scorers)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\evaluation\base.py", line 297, in evaluate
#     result, _ = _run_harness(data, scorers, predict_fn, model_id)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\telemetry\track.py", line 30, in wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\evaluation\base.py", line 390, in _run_harness
#     predict_fn = convert_predict_fn(predict_fn=predict_fn, sample_input=sample_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\trace_utils.py", line 576, in convert_predict_fn
#     check_model_prediction(predict_fn, sample_input)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\data_validation.py", line 33, in check_model_prediction
#     _validate_function_and_input_compatibility(predict_fn, sample_input, e)
#   File "c:\Users\edvin\.vscode\ELLA_fab4\.venv\Lib\site-packages\mlflow\genai\utils\data_validation.py", line 59, in _validate_function_and_input_compatibility
#     raise MlflowException.invalid_parameter_value(
# mlflow.exceptions.MlflowException: Failed to run the prediction function specified in the `predict_fn` parameter. Input: {'question': 'Vad Ã¤r straffet fÃ¶r mord?'}. Error: generator didn't stop after throw()
