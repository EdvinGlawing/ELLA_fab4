# %%
from mlflow.genai.prompts import register_prompt

law_agent_prompt = register_prompt(
    name="law-agent-system-prompt",
    template="Du är en jurist som svarar på frågor om brottsbalken",
    tags = {
        "author": "ella",
        "agent": "law_agent",
        "prompt_type": "system_prompt"
    }
)
law_agent_prompt
# Out:
# 2026/05/07 15:29:27 ERROR mlflow.store.db.utils: SQLAlchemy database error. The following exception is caught.
# (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: UPDATE registered_models SET last_updated_time=? WHERE registered_models.workspace = ? AND registered_models.name = ?]
# [parameters: (1778160567893, 'default', 'law-agent-system-prompt')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Traceback (most recent call last):
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py", line 952, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/db/utils.py", line 187, in make_managed_session
#     yield session
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py", line 991, in create_model_version
#     version = next_version(sql_registered_model)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py", line 952, in next_version
#     if sql_registered_model.model_versions:
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py", line 569, in __get__
#     return self.impl.get(state, dict_)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py", line 1096, in get
#     value = self._fire_loader_callables(state, key, passive)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py", line 1131, in _fire_loader_callables
#     return self.callable_(state, passive)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/strategies.py", line 978, in _load_for_state
#     return self._emit_lazyload(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/strategies.py", line 1141, in _emit_lazyload
#     result = session.execute(
#              ^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 2351, in execute
#     return self._execute_internal(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 2228, in _execute_internal
#     ) = compile_state_cls.orm_pre_session_exec(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/context.py", line 577, in orm_pre_session_exec
#     session._autoflush()
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 3051, in _autoflush
#     raise e.with_traceback(sys.exc_info()[2])
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 3040, in _autoflush
#     self.flush()
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 4331, in flush
#     self._flush(objects)
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 4466, in _flush
#     with util.safe_reraise():
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py", line 121, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py", line 4427, in _flush
#     flush_context.execute()
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py", line 85, in save_obj
#     _emit_update_statements(
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py", line 912, in _emit_update_statements
#     c = connection.execute(
#         ^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1419, in execute
#     return meth(
#            ^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py", line 527, in _execute_on_connection
#     return connection._execute_clauseelement(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1641, in _execute_clauseelement
#     ret = self._execute_context(
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1846, in _execute_context
#     return self._exec_single_context(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1986, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 2363, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/Users/lucaslindh/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py", line 952, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: UPDATE registered_models SET last_updated_time=? WHERE registered_models.workspace = ? AND registered_models.name = ?]
# [parameters: (1778160567893, 'default', 'law-agent-system-prompt')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/db/utils.py:187, in _get_managed_session_maker.<locals>.make_managed_session()
#     186     session.execute(sql.text("PRAGMA case_sensitive_like = true;"))
# --> 187 yield session
#     188 session.commit()
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:991, in SqlAlchemyStore.create_model_version(self, name, source, run_id, tags, run_link, description, local_model_path, model_id)
#     990 sql_registered_model.last_updated_time = creation_time
# --> 991 version = next_version(sql_registered_model)
#     992 model_version = self._with_workspace_field(
#     993     SqlModelVersion(
#     994         name=name,
#    (...)   1003     )
#    1004 )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:952, in SqlAlchemyStore.create_model_version.<locals>.next_version(sql_registered_model)
#     951 def next_version(sql_registered_model):
# --> 952     if sql_registered_model.model_versions:
#     953         return max(mv.version for mv in sql_registered_model.model_versions) + 1
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py:569, in InstrumentedAttribute.__get__(self, instance, owner)
#     568     raise orm_exc.UnmappedInstanceError(instance) from err
# --> 569 return self.impl.get(state, dict_)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py:1096, in AttributeImpl.get(self, state, dict_, passive)
#    1094     return PASSIVE_NO_RESULT
# -> 1096 value = self._fire_loader_callables(state, key, passive)
#    1098 if value is PASSIVE_NO_RESULT or value is NO_VALUE:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/attributes.py:1131, in AttributeImpl._fire_loader_callables(self, state, key, passive)
#    1130 elif self.callable_:
# -> 1131     return self.callable_(state, passive)
#    1132 else:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/strategies.py:978, in LazyLoader._load_for_state(self, state, passive, loadopt, extra_criteria, extra_options, alternate_effective_path, execution_options)
#     976         return LoaderCallableStatus.PASSIVE_NO_RESULT
# --> 978 return self._emit_lazyload(
#     979     session,
#     980     state,
#     981     primary_key_identity,
#     982     passive,
#     983     loadopt,
#     984     extra_criteria,
#     985     extra_options,
#     986     alternate_effective_path,
#     987     execution_options,
#     988 )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/strategies.py:1141, in LazyLoader._emit_lazyload(self, session, state, primary_key_identity, passive, loadopt, extra_criteria, extra_options, alternate_effective_path, execution_options)
#    1139 stmt._where_criteria = (lazy_clause,)
# -> 1141 result = session.execute(
#    1142     stmt, params, execution_options=execution_options
#    1143 )
#    1145 result = result.unique().scalars().all()
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2301 r"""Execute a SQL expression construct.
#    2302
#    2303 Returns a :class:`_engine.Result` object representing
#    (...)   2349
#    2350 """
# -> 2351 return self._execute_internal(
#    2352     statement,
#    2353     params,
#    2354     execution_options=execution_options,
#    2355     bind_arguments=bind_arguments,
#    2356     _parent_execute_state=_parent_execute_state,
#    2357     _add_event=_add_event,
#    2358 )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2228, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2219 if compile_state_cls is not None:
#    2220     # now run orm_pre_session_exec() "for real".   if there were
#    2221     # event hooks, this will re-run the steps that interpret
#    2222     # new execution_options into load_options / update_delete_options,
#    2223     # which we assume the event hook might have updated.
#    2224     # autoflush will also be invoked in this step if enabled.
#    2225     (
#    2226         statement,
#    2227         execution_options,
# -> 2228     ) = compile_state_cls.orm_pre_session_exec(
#    2229         self,
#    2230         statement,
#    2231         params,
#    2232         execution_options,
#    2233         bind_arguments,
#    2234         False,
#    2235     )
#    2237 bind = self.get_bind(**bind_arguments)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/context.py:577, in ORMCompileState.orm_pre_session_exec(cls, session, statement, params, execution_options, bind_arguments, is_pre_event)
#     576 if not is_pre_event and load_options._autoflush:
# --> 577     session._autoflush()
#     579 return statement, execution_options
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:3051, in Session._autoflush(self)
#    3046 e.add_detail(
#    3047     "raised as a result of Query-invoked autoflush; "
#    3048     "consider using a session.no_autoflush block if this "
#    3049     "flush is occurring prematurely"
#    3050 )
# -> 3051 raise e.with_traceback(sys.exc_info()[2])
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:3040, in Session._autoflush(self)
#    3039 try:
# -> 3040     self.flush()
#    3041 except sa_exc.StatementError as e:
#    3042     # note we are reraising StatementError as opposed to
#    3043     # raising FlushError with "chaining" to remain compatible
#    3044     # with code that catches StatementError, IntegrityError,
#    3045     # etc.
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:85, in save_obj(base_mapper, states, uowtransaction, single)
#      81 update = _collect_update_commands(
#      82     uowtransaction, table, states_to_update
#      83 )
# ---> 85 _emit_update_statements(
#      86     base_mapper,
#      87     uowtransaction,
#      88     mapper,
#      89     table,
#      90     update,
#      91 )
#      93 _emit_insert_statements(
#      94     base_mapper,
#      95     uowtransaction,
#    (...)     98     insert,
#      99 )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/orm/persistence.py:912, in _emit_update_statements(base_mapper, uowtransaction, mapper, table, update, bookkeeping, use_orm_update_stmt, enable_check_rowcount)
#     907 check_rowcount = enable_check_rowcount and (
#     908     assert_multirow
#     909     or (assert_singlerow and len(multiparams) == 1)
#     910 )
# --> 912 c = connection.execute(
#     913     statement, multiparams, execution_options=execution_options
#     914 )
#     916 rows += c.rowcount
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: UPDATE registered_models SET last_updated_time=? WHERE registered_models.workspace = ? AND registered_models.name = ?]
# [parameters: (1778160567893, 'default', 'law-agent-system-prompt')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 from mlflow.genai.prompts import register_prompt
#       2
# ----> 3 law_agent_prompt = register_prompt(
#       4     name="law-agent-system-prompt",
#       5     template="Du är en jurist som svarar på frågor om brottsbalken",
#       6     tags = {
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/prompt/registry_utils.py:209, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     203 if not is_prompt_supported_registry(registry_uri):
#     204     raise MlflowException(
#     205         f"The '{func.__name__}' API is not supported with the current registry. "
#     206         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     207         "legacy Databricks workspace registry.",
#     208     )
# --> 209 return func(*args, **kwargs)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/genai/prompts/__init__.py:136, in register_prompt(name, template, commit_message, tags, response_format, model_config)
#      42 """
#      43 Register a new :py:class:`Prompt <mlflow.entities.Prompt>` in the MLflow Prompt Registry.
#      44
#    (...)    133
#     134 """
#     135 with suppress_genai_migration_warning():
# --> 136     return registry_api.register_prompt(
#     137         name=name,
#     138         template=template,
#     139         commit_message=commit_message,
#     140         tags=tags,
#     141         response_format=response_format,
#     142         model_config=model_config,
#     143     )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/prompt/registry_utils.py:209, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     203 if not is_prompt_supported_registry(registry_uri):
#     204     raise MlflowException(
#     205         f"The '{func.__name__}' API is not supported with the current registry. "
#     206         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     207         "legacy Databricks workspace registry.",
#     208     )
# --> 209 return func(*args, **kwargs)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/tracking/_model_registry/fluent.py:684, in register_prompt(name, template, commit_message, tags, response_format, model_config)
#     588 """
#     589 Register a new :py:class:`Prompt <mlflow.entities.Prompt>` in the MLflow Prompt Registry.
#     590
#    (...)    676     )
#     677 """
#     678 warnings.warn(
#     679     PROMPT_API_MIGRATION_MSG.format(func_name="register_prompt"),
#     680     category=FutureWarning,
#     681     stacklevel=3,
#     682 )
# --> 684 return MlflowClient().register_prompt(
#     685     name=name,
#     686     template=template,
#     687     commit_message=commit_message,
#     688     tags=tags,
#     689     response_format=response_format,
#     690     model_config=model_config,
#     691 )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/prompt/registry_utils.py:209, in require_prompt_registry.<locals>.wrapper(*args, **kwargs)
#     203 if not is_prompt_supported_registry(registry_uri):
#     204     raise MlflowException(
#     205         f"The '{func.__name__}' API is not supported with the current registry. "
#     206         "Prompts are supported in OSS MLflow and Unity Catalog, but not in the "
#     207         "legacy Databricks workspace registry.",
#     208     )
# --> 209 return func(*args, **kwargs)
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/prompt/registry_utils.py:246, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     244     raise new_exc from e
#     245 else:
# --> 246     raise e
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/prompt/registry_utils.py:233, in translate_prompt_exception.<locals>.wrapper(*args, **kwargs)
#     230 @functools.wraps(func)
#     231 def wrapper(*args, **kwargs):
#     232     try:
# --> 233         return func(*args, **kwargs)
#     234     except MlflowException as e:
#     235         original_message = e.message
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:784, in MlflowClient.register_prompt(self, name, template, commit_message, tags, response_format, model_config)
#     781     tags.update({PROMPT_MODEL_CONFIG_TAG_KEY: json.dumps(config_dict)})
#     783 try:
# --> 784     mv: ModelVersion = registry_client.create_model_version(
#     785         name=name,
#     786         description=commit_message,
#     787         source="dummy-source",  # Required field, but not used for prompts
#     788         tags=tags,
#     789     )
#     790 except Exception:
#     791     if is_new_prompt:
#     792         # When a model version creation fails for the first version of a prompt,
#     793         # delete the registered model to avoid leaving a prompt with no versions
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/tracking/_model_registry/client.py:268, in ModelRegistryClient.create_model_version(self, name, source, run_id, tags, run_link, description, await_creation_for, local_model_path, model_id)
#     266 arg_names = _get_arg_names(self.store.create_model_version)
#     267 if "local_model_path" in arg_names:
# --> 268     mv = self.store.create_model_version(
#     269         name,
#     270         source,
#     271         run_id,
#     272         tags,
#     273         run_link,
#     274         description,
#     275         local_model_path=local_model_path,
#     276         model_id=model_id,
#     277     )
#     278 else:
#     279     # Fall back to calling create_model_version without
#     280     # local_model_path since old model registry store implementations may not
#     281     # support the local_model_path argument.
#     282     mv = self.store.create_model_version(
#     283         name, source, run_id, tags, run_link, description, model_id=model_id
#     284     )
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:985, in SqlAlchemyStore.create_model_version(self, name, source, run_id, tags, run_link, description, local_model_path, model_id)
#     982     model = MlflowClient().get_logged_model(model_id)
#     983     run_id = model.source_run_id
# --> 985 with self.ManagedSessionMaker() as session:
#     986     creation_time = get_current_time_millis()
#     987     for attempt in range(self.CREATE_MODEL_VERSION_RETRIES):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/MLOps/github/ELLA_fab4/.venv/lib/python3.12/site-packages/mlflow/store/db/utils.py:198, in _get_managed_session_maker.<locals>.make_managed_session()
#     193     session.rollback()
#     194     _logger.exception(
#     195         "SQLAlchemy database error. The following exception is caught.\n%s",
#     196         e,
#     197     )
# --> 198     raise MlflowException(message=e, error_code=TEMPORARILY_UNAVAILABLE) from e
#     199 except sqlalchemy.exc.SQLAlchemyError as e:
#     200     session.rollback()
#
# MlflowException: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: UPDATE registered_models SET last_updated_time=? WHERE registered_models.workspace = ? AND registered_models.name = ?]
# [parameters: (1778160567893, 'default', 'law-agent-system-prompt')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
law_agent_prompt.format()
# Out:
# 'Du är en jurist som svarar på frågor om brottsbalken'

# %%
import mlflow

# Ladda specifikt v2
prompt = mlflow.genai.load_prompt("prompts:/law-agent-system-prompt/2")

# Hämta ut själva textsträngen
system_prompt_text = prompt.template

# %%
system_prompt_text.format()
# Out:
# 'Du är en Edvin som svarar på frågor om brottsbalken'

# %%
print(mlflow.get_tracking_uri())
# Out:
# sqlite:///C:/Users/linus/Documents/github/ELLA_fab4/ELLA_fab4/src/brottsbalken/monitoring/mlflow.db

# %%
from mlflow.genai.prompts import register_prompt

law_agent_prompt = register_prompt(
    name="law-agent-system-prompt_1",
    template="""
Du är en juridisk informationsassistent som svarar på frågor om Brottsbalken.

Din uppgift:
Svara på frågor baserat på hämtad lagtext från Brottsbalken.
Förklara kort och tydligt.
Hänvisa alltid till kapitel och paragraf när det är möjligt.

Viktiga regler:
Svara endast baserat på den hämtade lagtexten.
Om den hämtade lagtexten inte tydligt besvarar frågan, svara:"Jag hittar inget stöd i Brottsbalken för att svara på den frågan."
Ge inte personlig juridisk rådgivning.
Gissa inte.
Använd inte allmän kunskap.
Om frågan inte handlar om Brottsbalken, svara:"Jag hittar inget stöd i Brottsbalken för att svara på den frågan."
Skriv på svenska.
""",
    tags={
        "author": "fab4",
        "agent": "law_agent",
        "prompt_type": "system_prompt",
        "domain": "brottsbalken",
    },
)

law_agent_prompt
# Out:
# PromptVersion(name=law-agent-system-prompt_1, version=1, template=
# Du är en juridisk information...)

# %%
law_agent_prompt.format()
# Out:
# '\nDu är en juridisk informationsassistent som svarar på frågor om Brottsbalken.\n\nDin uppgift:\nSvara på frågor baserat på hämtad lagtext från Brottsbalken.\nFörklara kort och tydligt.\nHänvisa alltid till kapitel och paragraf när det är möjligt.\n\nViktiga regler:\nSvara endast baserat på den hämtade lagtexten.\nOm den hämtade lagtexten inte tydligt besvarar frågan, svara:"Jag hittar inget stöd i Brottsbalken för att svara på den frågan."\nGe inte personlig juridisk rådgivning.\nGissa inte.\nAnvänd inte allmän kunskap.\nOm frågan inte handlar om Brottsbalken, svara:"Jag hittar inget stöd i Brottsbalken för att svara på den frågan."\nSkriv på svenska.\n'

# %%
from mlflow.genai.prompts import register_prompt

law_agent_prompt = register_prompt(
    name="law-agent-system-prompt",
    template="""Du är en clown som luras och skojar. Svara på frågor baserat på hämtad lagtext från Brottsbalken. Du drar skämt och försöker alltid få in en rolig twist i svaret. Svara på svenska.

""",
    tags={
        "author": "fab4",
        "agent": "law_agent",
        "prompt_type": "system_prompt",
        "domain": "brottsbalken",
    },
)

law_agent_prompt
